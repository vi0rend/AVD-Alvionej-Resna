# %% [markdown]
# <a href="https://colab.research.google.com/github/vi0rend/AVD-Alvionej-Resna/blob/main/Praktikum_AVD_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
file_path = "/topuniversities.csv"

df = pd.read_csv(file_path)
df
# Out:
#      Rank  Ordinal Rank                           University Name  \
# 0       1             1                         Peking University
# 1       2             2               The University of Hong Kong
# 2       3             3    National University of Singapore (NUS)
# 3       4             4          Nanyang Technological University
# 4       5             5                          Fudan University
# ..    ...           ...                                       ...
# 295   296           296  National Chinyi University of Technology
# 296   297           296               Sungshin Women's University
# 297   298           298              Northwest University (China)
# 298   299           299                 Ocean University of China
# 299   300           300          Huazhong Agricultural University
#
#      Overall Score           City      Country  Citations per Paper  \
# 0            100.0        Beijing        China                 96.4
# 1             99.7       Pokfulam    Hong Kong                 99.5
# 2             98.9      Singapore    Singapore                 99.9
# 3             98.3      Singapore    Singapore                100.0
# 4             97.2       Shanghai        China                 92.1
# ..             ...            ...          ...                  ...
# 295           29.5  Taichung City       Taiwan                 25.8
# 296           29.5          Seoul  South Korea                  9.1
# 297           29.2          Xi'an        China                 64.5
# 298           29.1        Qingdao        China                 48.1
# 299           29.0          Wuhan        China                 91.5
#
#      Papers per Faculty  Academic Reputation  Faculty Student Ratio  \
# 0                  79.8                100.0                   98.6
# 1                  55.0                100.0                   93.3
# 2                  57.4                100.0                   85.8
# 3                  53.8                100.0                   93.0
# 4                  63.1                 99.8                   92.5
# ..                  ...                  ...                    ...
# 295                15.9                 31.9                   12.9
# 296                 2.1                 21.4                   93.0
# 297                27.4                 16.1                   69.5
# 298                60.5                 20.8                   13.9
# 299                52.2                 16.7                   12.1
#
#      Staff with PhD  International Research Center  International Students  \
# 0              90.7                           98.0                    69.1
# 1              97.4                           98.4                   100.0
# 2              82.5                           99.9                    99.2
# 3              67.0                           99.7                    98.8
# 4              73.4                           92.1                    81.0
# ..              ...                            ...                     ...
# 295            52.1                           11.5                    29.8
# 296            18.6                            2.5                    22.5
# 297            17.5                           49.7                    13.3
# 298            33.0                           76.4                     6.5
# 299            61.0                           45.6                     6.6
#
#      Outbound Exchange  Inbound Exchange  International Faculty  \
# 0                100.0              88.5                   83.2
# 1                100.0              99.8                  100.0
# 2                 97.6              93.4                  100.0
# 3                 97.9              90.5                  100.0
# 4                 94.9              99.5                   98.9
# ..                 ...               ...                    ...
# 295                3.4              17.2                    5.1
# 296               85.5              44.6                    7.7
# 297               47.9               6.1                   10.6
# 298               27.3               2.8                    8.5
# 299               11.5               1.5                   11.7
#
#      Employer Reputation
# 0                  100.0
# 1                   96.8
# 2                   99.9
# 3                   98.8
# 4                   99.5
# ..                   ...
# 295                 46.7
# 296                 33.9
# 297                  5.3
# 298                 12.4
# 299                  9.3
#
# [300 rows x 17 columns]

# %% [markdown]
# # **BUSINESS UNDERSTANDING**
#
# **Business Objective**
#
# Tujuan utama dari proyek ini adalah untuk memahami faktor-faktor yang berkontribusi terhadap peringkat universitas di Asia berdasarkan QS Rankings 2024. Dengan menganalisis berbagai metrik seperti reputasi akademik, rasio fakultas terhadap mahasiswa, penelitian internasional, dan jumlah mahasiswa internasional, proyek ini bertujuan untuk mengidentifikasi pola yang memungkinkan universitas meningkatkan daya saing mereka. Selain itu, proyek ini juga bertujuan untuk memberikan wawasan bagi calon mahasiswa dan pemangku kepentingan dalam memilih institusi pendidikan terbaik.
#
# **Assess Situation**
#
# Industri pendidikan tinggi di Asia semakin kompetitif dengan banyak universitas yang berupaya meningkatkan kualitas akademik dan penelitian mereka. Perubahan dalam kebijakan pendidikan, tingkat internasionalisasi, serta reputasi akademik dan kerja turut memengaruhi peringkat universitas. Oleh karena itu, analisis mendalam terhadap data peringkat universitas menjadi penting untuk mengidentifikasi tren dan faktor yang memengaruhi daya saing institusi pendidikan.
#
# **Data Mining Goals**
#
# Menganalisis faktor-faktor utama yang memengaruhi peringkat universitas di Asia dengan mengidentifikasi hubungan antara berbagai metrik seperti reputasi akademik, jumlah sitasi per publikasi, jumlah mahasiswa internasional, serta tingkat pertukaran mahasiswa. Analisis ini juga bertujuan untuk memberikan wawasan tentang bagaimana universitas dapat meningkatkan kualitas akademik dan reputasi mereka dalam skala global.
#
# **Project Plan**
#
# Proyek ini dimulai dengan mengumpulkan dan membersihkan data dari QS Asian Rankings 2024. Data yang dikumpulkan mencakup indikator seperti reputasi akademik, jumlah sitasi per publikasi, rasio fakultas terhadap mahasiswa, dan jumlah mahasiswa internasional. Pembersihan data dilakukan untuk memastikan akurasi dan menghilangkan anomali.
#
# Setelah itu, dilakukan analisis statistik untuk menemukan pola dan hubungan antara faktor-faktor yang memengaruhi peringkat universitas. Hasilnya akan disajikan dalam bentuk laporan dan visualisasi agar mudah dipahami oleh pemangku kepentingan. Proyek ini diakhiri dengan rekomendasi bagi universitas yang ingin meningkatkan daya saing mereka di tingkat internasional.

# %% [markdown]
# # DATA UNDERSTANDING
#
# menampilkan ringkasan dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rank                           300 non-null    int64
#  1   Ordinal Rank                   300 non-null    int64
#  2   University Name                300 non-null    object
#  3   Overall Score                  300 non-null    float64
#  4   City                           300 non-null    object
#  5   Country                        300 non-null    object
#  6   Citations per Paper            300 non-null    float64
#  7   Papers per Faculty             300 non-null    float64
#  8   Academic Reputation            300 non-null    float64
#  9   Faculty Student Ratio          300 non-null    float64
#  10  Staff with PhD                 294 non-null    float64
#  11  International Research Center  300 non-null    float64
#  12  International Students         296 non-null    float64
#  13  Outbound Exchange              300 non-null    float64
#  14  Inbound Exchange               300 non-null    float64
#  15  International Faculty          283 non-null    float64
#  16  Employer Reputation            300 non-null    float64
# dtypes: float64(12), int64(2), object(3)
# memory usage: 40.0+ KB

# %% [markdown]
# Menampilkan jumlah baris dan kolom

# %%
df.shape
# Out:
# (300, 17)

# %% [markdown]
# Menghitung Korelasi Antar Kolom Numerik

# %%
df.corr(numeric_only=True)
# Out:
#                                    Rank  Ordinal Rank  Overall Score  \
# Rank                           1.000000      0.999968      -0.954643
# Ordinal Rank                   0.999968      1.000000      -0.954562
# Overall Score                 -0.954643     -0.954562       1.000000
# Citations per Paper           -0.219652     -0.219700       0.268052
# Papers per Faculty            -0.293990     -0.293435       0.312004
# Academic Reputation           -0.862827     -0.862998       0.896955
# Faculty Student Ratio         -0.403355     -0.403051       0.454798
# Staff with PhD                -0.446959     -0.446609       0.455516
# International Research Center -0.468019     -0.468167       0.488723
# International Students        -0.462322     -0.461754       0.513554
# Outbound Exchange             -0.370927     -0.370235       0.409723
# Inbound Exchange              -0.433121     -0.432346       0.469792
# International Faculty         -0.404889     -0.404527       0.427801
# Employer Reputation           -0.761246     -0.761367       0.763001
#
#                                Citations per Paper  Papers per Faculty  \
# Rank                                     -0.219652           -0.293990
# Ordinal Rank                             -0.219700           -0.293435
# Overall Score                             0.268052            0.312004
# Citations per Paper                       1.000000            0.486041
# Papers per Faculty                        0.486041            1.000000
# Academic Reputation                      -0.064392            0.117506
# Faculty Student Ratio                     0.004107           -0.163080
# Staff with PhD                            0.276578            0.559372
# International Research Center             0.452921            0.536401
# International Students                    0.084009           -0.121409
# Outbound Exchange                         0.175227           -0.045673
# Inbound Exchange                          0.077214           -0.119361
# International Faculty                     0.043004           -0.119792
# Employer Reputation                      -0.143369           -0.029458
#
#                                Academic Reputation  Faculty Student Ratio  \
# Rank                                     -0.862827              -0.403355
# Ordinal Rank                             -0.862998              -0.403051
# Overall Score                             0.896955               0.454798
# Citations per Paper                      -0.064392               0.004107
# Papers per Faculty                        0.117506              -0.163080
# Academic Reputation                       1.000000               0.358035
# Faculty Student Ratio                     0.358035               1.000000
# Staff with PhD                            0.297581               0.110463
# International Research Center             0.333821              -0.097136
# International Students                    0.391102               0.476343
# Outbound Exchange                         0.242586               0.435891
# Inbound Exchange                          0.332274               0.462519
# International Faculty                     0.361890               0.359099
# Employer Reputation                       0.793638               0.216891
#
#                                Staff with PhD  International Research Center  \
# Rank                                -0.446959                      -0.468019
# Ordinal Rank                        -0.446609                      -0.468167
# Overall Score                        0.455516                       0.488723
# Citations per Paper                  0.276578                       0.452921
# Papers per Faculty                   0.559372                       0.536401
# Academic Reputation                  0.297581                       0.333821
# Faculty Student Ratio                0.110463                      -0.097136
# Staff with PhD                       1.000000                       0.320523
# International Research Center        0.320523                       1.000000
# International Students               0.219162                      -0.001793
# Outbound Exchange                    0.138828                      -0.089033
# Inbound Exchange                     0.164336                      -0.058656
# International Faculty                0.059475                      -0.098278
# Employer Reputation                  0.112035                       0.129727
#
#                                International Students  Outbound Exchange  \
# Rank                                        -0.462322          -0.370927
# Ordinal Rank                                -0.461754          -0.370235
# Overall Score                                0.513554           0.409723
# Citations per Paper                          0.084009           0.175227
# Papers per Faculty                          -0.121409          -0.045673
# Academic Reputation                          0.391102           0.242586
# Faculty Student Ratio                        0.476343           0.435891
# Staff with PhD                               0.219162           0.138828
# International Research Center               -0.001793          -0.089033
# International Students                       1.000000           0.606147
# Outbound Exchange                            0.606147           1.000000
# Inbound Exchange                             0.647472           0.772452
# International Faculty                        0.629185           0.576159
# Employer Reputation                          0.330461           0.205801
#
#                                Inbound Exchange  International Faculty  \
# Rank                                  -0.433121              -0.404889
# Ordinal Rank                          -0.432346              -0.404527
# Overall Score                          0.469792               0.427801
# Citations per Paper                    0.077214               0.043004
# Papers per Faculty                    -0.119361              -0.119792
# Academic Reputation                    0.332274               0.361890
# Faculty Student Ratio                  0.462519               0.359099
# Staff with PhD                         0.164336               0.059475
# International Research Center         -0.058656              -0.098278
# International Students                 0.647472               0.629185
# Outbound Exchange                      0.772452               0.576159
# Inbound Exchange                       1.000000               0.581555
# International Faculty                  0.581555               1.000000
# Employer Reputation                    0.301433               0.316139
#
#                                Employer Reputation
# Rank                                     -0.761246
# Ordinal Rank                             -0.761367
# Overall Score                             0.763001
# Citations per Paper                      -0.143369
# Papers per Faculty                       -0.029458
# Academic Reputation                       0.793638
# Faculty Student Ratio                     0.216891
# Staff with PhD                            0.112035
# International Research Center             0.129727
# International Students                    0.330461
# Outbound Exchange                         0.205801
# Inbound Exchange                          0.301433
# International Faculty                     0.316139
# Employer Reputation                       1.000000

# %% [markdown]
# Menampilkan Statistik Deskriptif

# %%
df.describe()
# Out:
#              Rank  Ordinal Rank  Overall Score  Citations per Paper  \
# count  300.000000    300.000000     300.000000           300.000000
# mean   150.500000    150.133333      52.057667            44.869667
# std     86.746758     86.556739      19.123336            34.088756
# min      1.000000      1.000000      29.000000             1.000000
# 25%     75.750000     75.750000      35.850000            11.075000
# 50%    150.500000    150.500000      46.250000            39.050000
# 75%    225.250000    225.250000      62.725000            76.150000
# max    300.000000    300.000000     100.000000           100.000000
#
#        Papers per Faculty  Academic Reputation  Faculty Student Ratio  \
# count          300.000000           300.000000             300.000000
# mean            41.288667            51.648000              50.976333
# std             29.994062            26.305925              31.338651
# min              1.200000             8.800000               2.600000
# 25%             14.500000            30.100000              21.750000
# 50%             36.750000            45.150000              47.850000
# 75%             61.775000            67.550000              80.300000
# max            100.000000           100.000000             100.000000
#
#        Staff with PhD  International Research Center  International Students  \
# count      294.000000                     300.000000              296.000000
# mean        53.959524                      60.108333               35.779054
# std         35.002787                      31.179020               31.477270
# min          1.000000                       1.100000                1.300000
# 25%         15.850000                      33.475000                9.175000
# 50%         62.300000                      67.100000               23.950000
# 75%         86.800000                      88.675000               58.100000
# max        100.000000                     100.000000              100.000000
#
#        Outbound Exchange  Inbound Exchange  International Faculty  \
# count         300.000000        300.000000             283.000000
# mean           38.573667         35.303667              38.437456
# std            34.467015         36.086228              30.571068
# min             1.000000          1.000000               1.000000
# 25%             8.300000          3.300000              12.800000
# 50%            28.100000         20.100000              29.500000
# 75%            62.925000         67.800000              56.850000
# max           100.000000        100.000000             100.000000
#
#        Employer Reputation
# count           300.000000
# mean             54.646000
# std              29.915534
# min               4.100000
# 25%              28.150000
# 50%              53.050000
# 75%              81.850000
# max             100.000000

# %% [markdown]
# # Data Preparation
#
#
# Missing Values

# %%
(df.isna().sum() / len(df)) * 100
# Out:
# Rank                             0.000000
# Ordinal Rank                     0.000000
# University Name                  0.000000
# Overall Score                    0.000000
# City                             0.000000
# Country                          0.000000
# Citations per Paper              0.000000
# Papers per Faculty               0.000000
# Academic Reputation              0.000000
# Faculty Student Ratio            0.000000
# Staff with PhD                   2.000000
# International Research Center    0.000000
# International Students           1.333333
# Outbound Exchange                0.000000
# Inbound Exchange                 0.000000
# International Faculty            5.666667
# Employer Reputation              0.000000
# dtype: float64

# %% [markdown]
# melakukan imputansi

# %%
df['International Faculty'].dropna().describe()
# Out:
# count    283.000000
# mean      38.437456
# std       30.571068
# min        1.000000
# 25%       12.800000
# 50%       29.500000
# 75%       56.850000
# max      100.000000
# Name: International Faculty, dtype: float64

# %%
df['International Students'].dropna().describe()
# Out:
# count    296.000000
# mean      35.779054
# std       31.477270
# min        1.300000
# 25%        9.175000
# 50%       23.950000
# 75%       58.100000
# max      100.000000
# Name: International Students, dtype: float64

# %%
df['Staff with PhD'].dropna().describe()
# Out:
# count    294.000000
# mean      53.959524
# std       35.002787
# min        1.000000
# 25%       15.850000
# 50%       62.300000
# 75%       86.800000
# max      100.000000
# Name: Staff with PhD, dtype: float64

# %% [markdown]
# Menghapus Missing Values

# %%
df.fillna({
    'Staff with PhD': df['Staff with PhD'].median(),
    'International Students': df['International Students'].median(),
    'International Faculty': df['International Faculty'].median()
}, inplace=True)

# %%
df
# Out:
#      Rank  Ordinal Rank                           University Name  \
# 0       1             1                         Peking University
# 1       2             2               The University of Hong Kong
# 2       3             3    National University of Singapore (NUS)
# 3       4             4          Nanyang Technological University
# 4       5             5                          Fudan University
# ..    ...           ...                                       ...
# 295   296           296  National Chinyi University of Technology
# 296   297           296               Sungshin Women's University
# 297   298           298              Northwest University (China)
# 298   299           299                 Ocean University of China
# 299   300           300          Huazhong Agricultural University
#
#      Overall Score           City      Country  Citations per Paper  \
# 0            100.0        Beijing        China                 96.4
# 1             99.7       Pokfulam    Hong Kong                 99.5
# 2             98.9      Singapore    Singapore                 99.9
# 3             98.3      Singapore    Singapore                100.0
# 4             97.2       Shanghai        China                 92.1
# ..             ...            ...          ...                  ...
# 295           29.5  Taichung City       Taiwan                 25.8
# 296           29.5          Seoul  South Korea                  9.1
# 297           29.2          Xi'an        China                 64.5
# 298           29.1        Qingdao        China                 48.1
# 299           29.0          Wuhan        China                 91.5
#
#      Papers per Faculty  Academic Reputation  Faculty Student Ratio  \
# 0                  79.8                100.0                   98.6
# 1                  55.0                100.0                   93.3
# 2                  57.4                100.0                   85.8
# 3                  53.8                100.0                   93.0
# 4                  63.1                 99.8                   92.5
# ..                  ...                  ...                    ...
# 295                15.9                 31.9                   12.9
# 296                 2.1                 21.4                   93.0
# 297                27.4                 16.1                   69.5
# 298                60.5                 20.8                   13.9
# 299                52.2                 16.7                   12.1
#
#      Staff with PhD  International Research Center  International Students  \
# 0              90.7                           98.0                    69.1
# 1              97.4                           98.4                   100.0
# 2              82.5                           99.9                    99.2
# 3              67.0                           99.7                    98.8
# 4              73.4                           92.1                    81.0
# ..              ...                            ...                     ...
# 295            52.1                           11.5                    29.8
# 296            18.6                            2.5                    22.5
# 297            17.5                           49.7                    13.3
# 298            33.0                           76.4                     6.5
# 299            61.0                           45.6                     6.6
#
#      Outbound Exchange  Inbound Exchange  International Faculty  \
# 0                100.0              88.5                   83.2
# 1                100.0              99.8                  100.0
# 2                 97.6              93.4                  100.0
# 3                 97.9              90.5                  100.0
# 4                 94.9              99.5                   98.9
# ..                 ...               ...                    ...
# 295                3.4              17.2                    5.1
# 296               85.5              44.6                    7.7
# 297               47.9               6.1                   10.6
# 298               27.3               2.8                    8.5
# 299               11.5               1.5                   11.7
#
#      Employer Reputation
# 0                  100.0
# 1                   96.8
# 2                   99.9
# 3                   98.8
# 4                   99.5
# ..                   ...
# 295                 46.7
# 296                 33.9
# 297                  5.3
# 298                 12.4
# 299                  9.3
#
# [300 rows x 17 columns]

# %% [markdown]
# Duplicate values

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Rank, Ordinal Rank, University Name, Overall Score, City, Country, Citations per Paper, Papers per Faculty, Academic Reputation, Faculty Student Ratio, International Research Center, Outbound Exchange, Inbound Exchange, Employer Reputation]
# Index: []

# %% [markdown]
# Outliers

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                          Persentase Outliers
# Rank                                           0.0
# Ordinal Rank                                   0.0
# Overall Score                                  0.0
# Citations per Paper                            0.0
# Papers per Faculty                             0.0
# Academic Reputation                            0.0
# Faculty Student Ratio                          0.0
# International Research Center                  0.0
# Outbound Exchange                              0.0
# Inbound Exchange                               0.0
# Employer Reputation                            0.0

# %% [markdown]
# data tidak memiliki outliers

# %% [markdown]
# Inconsistent Value

# %%
df
# Out:
#      Rank  Ordinal Rank                           University Name  \
# 0       1             1                         Peking University
# 1       2             2               The University of Hong Kong
# 2       3             3    National University of Singapore (NUS)
# 3       4             4          Nanyang Technological University
# 4       5             5                          Fudan University
# ..    ...           ...                                       ...
# 295   296           296  National Chinyi University of Technology
# 296   297           296               Sungshin Women's University
# 297   298           298              Northwest University (China)
# 298   299           299                 Ocean University of China
# 299   300           300          Huazhong Agricultural University
#
#      Overall Score           City      Country  Citations per Paper  \
# 0            100.0        Beijing        China                 96.4
# 1             99.7       Pokfulam    Hong Kong                 99.5
# 2             98.9      Singapore    Singapore                 99.9
# 3             98.3      Singapore    Singapore                100.0
# 4             97.2       Shanghai        China                 92.1
# ..             ...            ...          ...                  ...
# 295           29.5  Taichung City       Taiwan                 25.8
# 296           29.5          Seoul  South Korea                  9.1
# 297           29.2          Xi'an        China                 64.5
# 298           29.1        Qingdao        China                 48.1
# 299           29.0          Wuhan        China                 91.5
#
#      Papers per Faculty  Academic Reputation  Faculty Student Ratio  \
# 0                  79.8                100.0                   98.6
# 1                  55.0                100.0                   93.3
# 2                  57.4                100.0                   85.8
# 3                  53.8                100.0                   93.0
# 4                  63.1                 99.8                   92.5
# ..                  ...                  ...                    ...
# 295                15.9                 31.9                   12.9
# 296                 2.1                 21.4                   93.0
# 297                27.4                 16.1                   69.5
# 298                60.5                 20.8                   13.9
# 299                52.2                 16.7                   12.1
#
#      International Research Center  Outbound Exchange  Inbound Exchange  \
# 0                             98.0              100.0              88.5
# 1                             98.4              100.0              99.8
# 2                             99.9               97.6              93.4
# 3                             99.7               97.9              90.5
# 4                             92.1               94.9              99.5
# ..                             ...                ...               ...
# 295                           11.5                3.4              17.2
# 296                            2.5               85.5              44.6
# 297                           49.7               47.9               6.1
# 298                           76.4               27.3               2.8
# 299                           45.6               11.5               1.5
#
#      Employer Reputation
# 0                  100.0
# 1                   96.8
# 2                   99.9
# 3                   98.8
# 4                   99.5
# ..                   ...
# 295                 46.7
# 296                 33.9
# 297                  5.3
# 298                 12.4
# 299                  9.3
#
# [300 rows x 14 columns]

# %% [markdown]
# tidak ada inconsistent value

# %% [markdown]
# Construct Data

# %%
df['Research Score'] = (df['Citations per Paper'].astype(float) + df['Papers per Faculty'].astype(float)) / 2
df['International Score'] = (df['International Students'].astype(float) + df['International Faculty'].astype(float) + df['International Research Center'].astype(float)) / 3
df['Academic Environment'] = (df['Academic Reputation'].astype(float) + df['Faculty Student Ratio'].astype(float) + df['Staff with PhD'].astype(float)) / 3

# %%
df
# Out:
#      Rank  Ordinal Rank                           University Name  \
# 0       1             1                         Peking University
# 1       2             2               The University of Hong Kong
# 2       3             3    National University of Singapore (NUS)
# 3       4             4          Nanyang Technological University
# 4       5             5                          Fudan University
# ..    ...           ...                                       ...
# 295   296           296  National Chinyi University of Technology
# 296   297           296               Sungshin Women's University
# 297   298           298              Northwest University (China)
# 298   299           299                 Ocean University of China
# 299   300           300          Huazhong Agricultural University
#
#      Overall Score           City      Country  Citations per Paper  \
# 0            100.0        Beijing        China                 96.4
# 1             99.7       Pokfulam    Hong Kong                 99.5
# 2             98.9      Singapore    Singapore                 99.9
# 3             98.3      Singapore    Singapore                100.0
# 4             97.2       Shanghai        China                 92.1
# ..             ...            ...          ...                  ...
# 295           29.5  Taichung City       Taiwan                 25.8
# 296           29.5          Seoul  South Korea                  9.1
# 297           29.2          Xi'an        China                 64.5
# 298           29.1        Qingdao        China                 48.1
# 299           29.0          Wuhan        China                 91.5
#
#      Papers per Faculty  Academic Reputation  Faculty Student Ratio  \
# 0                  79.8                100.0                   98.6
# 1                  55.0                100.0                   93.3
# 2                  57.4                100.0                   85.8
# 3                  53.8                100.0                   93.0
# 4                  63.1                 99.8                   92.5
# ..                  ...                  ...                    ...
# 295                15.9                 31.9                   12.9
# 296                 2.1                 21.4                   93.0
# 297                27.4                 16.1                   69.5
# 298                60.5                 20.8                   13.9
# 299                52.2                 16.7                   12.1
#
#      Staff with PhD  International Research Center  International Students  \
# 0              90.7                           98.0                    69.1
# 1              97.4                           98.4                   100.0
# 2              82.5                           99.9                    99.2
# 3              67.0                           99.7                    98.8
# 4              73.4                           92.1                    81.0
# ..              ...                            ...                     ...
# 295            52.1                           11.5                    29.8
# 296            18.6                            2.5                    22.5
# 297            17.5                           49.7                    13.3
# 298            33.0                           76.4                     6.5
# 299            61.0                           45.6                     6.6
#
#      Outbound Exchange  Inbound Exchange  International Faculty  \
# 0                100.0              88.5                   83.2
# 1                100.0              99.8                  100.0
# 2                 97.6              93.4                  100.0
# 3                 97.9              90.5                  100.0
# 4                 94.9              99.5                   98.9
# ..                 ...               ...                    ...
# 295                3.4              17.2                    5.1
# 296               85.5              44.6                    7.7
# 297               47.9               6.1                   10.6
# 298               27.3               2.8                    8.5
# 299               11.5               1.5                   11.7
#
#      Employer Reputation  Research Score  International Score  \
# 0                  100.0           88.10            83.433333
# 1                   96.8           77.25            99.466667
# 2                   99.9           78.65            99.700000
# 3                   98.8           76.90            99.500000
# 4                   99.5           77.60            90.666667
# ..                   ...             ...                  ...
# 295                 46.7           20.85            15.466667
# 296                 33.9            5.60            10.900000
# 297                  5.3           45.95            24.533333
# 298                 12.4           54.30            30.466667
# 299                  9.3           71.85            21.300000
#
#      Academic Environment
# 0               96.433333
# 1               96.900000
# 2               89.433333
# 3               86.666667
# 4               88.566667
# ..                    ...
# 295             32.300000
# 296             44.333333
# 297             34.366667
# 298             22.566667
# 299             29.933333
#
# [300 rows x 20 columns]

# %% [markdown]
# Data Reduction

# %%
df = df.drop('City', axis=1)
df = df.drop('Country', axis=1)

# %%
df
# Out:
#      Rank  Ordinal Rank                           University Name  \
# 0       1             1                         Peking University
# 1       2             2               The University of Hong Kong
# 2       3             3    National University of Singapore (NUS)
# 3       4             4          Nanyang Technological University
# 4       5             5                          Fudan University
# ..    ...           ...                                       ...
# 295   296           296  National Chinyi University of Technology
# 296   297           296               Sungshin Women's University
# 297   298           298              Northwest University (China)
# 298   299           299                 Ocean University of China
# 299   300           300          Huazhong Agricultural University
#
#      Overall Score  Citations per Paper  Papers per Faculty  \
# 0            100.0                 96.4                79.8
# 1             99.7                 99.5                55.0
# 2             98.9                 99.9                57.4
# 3             98.3                100.0                53.8
# 4             97.2                 92.1                63.1
# ..             ...                  ...                 ...
# 295           29.5                 25.8                15.9
# 296           29.5                  9.1                 2.1
# 297           29.2                 64.5                27.4
# 298           29.1                 48.1                60.5
# 299           29.0                 91.5                52.2
#
#      Academic Reputation  Faculty Student Ratio  Staff with PhD  \
# 0                  100.0                   98.6            90.7
# 1                  100.0                   93.3            97.4
# 2                  100.0                   85.8            82.5
# 3                  100.0                   93.0            67.0
# 4                   99.8                   92.5            73.4
# ..                   ...                    ...             ...
# 295                 31.9                   12.9            52.1
# 296                 21.4                   93.0            18.6
# 297                 16.1                   69.5            17.5
# 298                 20.8                   13.9            33.0
# 299                 16.7                   12.1            61.0
#
#      International Research Center  International Students  Outbound Exchange  \
# 0                             98.0                    69.1              100.0
# 1                             98.4                   100.0              100.0
# 2                             99.9                    99.2               97.6
# 3                             99.7                    98.8               97.9
# 4                             92.1                    81.0               94.9
# ..                             ...                     ...                ...
# 295                           11.5                    29.8                3.4
# 296                            2.5                    22.5               85.5
# 297                           49.7                    13.3               47.9
# 298                           76.4                     6.5               27.3
# 299                           45.6                     6.6               11.5
#
#      Inbound Exchange  International Faculty  Employer Reputation  \
# 0                88.5                   83.2                100.0
# 1                99.8                  100.0                 96.8
# 2                93.4                  100.0                 99.9
# 3                90.5                  100.0                 98.8
# 4                99.5                   98.9                 99.5
# ..                ...                    ...                  ...
# 295              17.2                    5.1                 46.7
# 296              44.6                    7.7                 33.9
# 297               6.1                   10.6                  5.3
# 298               2.8                    8.5                 12.4
# 299               1.5                   11.7                  9.3
#
#      Research Score  International Score  Academic Environment
# 0             88.10            83.433333             96.433333
# 1             77.25            99.466667             96.900000
# 2             78.65            99.700000             89.433333
# 3             76.90            99.500000             86.666667
# 4             77.60            90.666667             88.566667
# ..              ...                  ...                   ...
# 295           20.85            15.466667             32.300000
# 296            5.60            10.900000             44.333333
# 297           45.95            24.533333             34.366667
# 298           54.30            30.466667             22.566667
# 299           71.85            21.300000             29.933333
#
# [300 rows x 18 columns]

# %%
output_path ="/content/topuniversities.csv"
df.to_csv(output_path, index=False)

print("\nData berhasil disimpan sebagai file Excel:", output_path)
# Out:
# Data berhasil disimpan sebagai file Excel: /content/topuniversities.csv
